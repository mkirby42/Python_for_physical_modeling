# %% [markdown]
# # Contour Plots and Surface Plots

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Generating a grid of points

# %%
x_vals = np.linspace(-3, 3, 21)
y_vals = np.linspace(0, 10, 11)
x, y = np.meshgrid(x_vals, y_vals)

# %% [markdown]
# ## Contour plots

# %%
z = np.cos(x) * np.sin(y)
plt.contour(x, y, z, 30)

# %%
cs = plt.contour(x, y, z,
                 10,
                 linewidths = 3,
                 colors = 'k')

plt.clabel(cs, fontsize = 10)
# Out:
# <a list of 34 text.Text objects>

# %%
cs = plt.contourf(x, y, z, 20)
plt.set_cmap('autumn')

# %% [markdown]
# ## Surface plots

# %%
from mpl_toolkits.mplot3d import Axes3D

# %%
ax = Axes3D(plt.figure())
ax.plot_surface(x, y, z)

# %%
ax = Axes3D(plt.figure())

ax.plot_surface(x, y, z,
                rstride = 1,
                cstride = 1)

# %% [markdown]
# ## Practice
#
# Make a surface plot of the function z = x2 + y2 over a suitable grid of
# values, where x and y range from -1 to 1.

# %%
x_vals = np.linspace(-1, 1)
y_vals = np.linspace(-1, 1)
x, y = np.meshgrid(x_vals, y_vals)

# %%
z = x**2 * y**2

ax = Axes3D(plt.figure())

ax.plot_surface(x, y, z,
                rstride = 1,
                cstride = 1,
                cmap = 'cool')
